# %%
# !pip install mlflow boto3 awscli
# Out:
# Requirement already satisfied: mlflow in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.14.0)
# Requirement already satisfied: boto3 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.43.78)
# Requirement already satisfied: awscli in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.46.0)
# Requirement already satisfied: mlflow-skinny==3.14.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow) (3.14.0)
# Requirement already satisfied: mlflow-tracing==3.14.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow) (3.14.0)
# Requirement already satisfied: Flask-CORS<7 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow) (6.0.5)
# Requirement already satisfied: Flask<4 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow) (3.1.3)
# Requirement already satisfied: aiohttp<4,>=3.7.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow) (3.14.1)
# Requirement already satisfied: alembic!=1.10.0,<2 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow) (1.18.5)
# Requirement already satisfied: cryptography<49,>=43.0.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow) (48.0.1)
# Requirement already satisfied: docker<8,>=4.0.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: huey<4,>=2.5.4 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow) (3.0.3)
# Requirement already satisfied: matplotlib<4 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow) (3.11.0)
# Requirement already satisfied: numpy<3 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow) (2.5.0)
# Requirement already satisfied: pandas<3 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: pyarrow<25,>=4.0.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow) (24.0.0)
# Requirement already satisfied: scikit-learn<2 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow) (1.9.0)
# Requirement already satisfied: scipy<2 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow) (1.18.0)
# Requirement already satisfied: skops<1 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow) (0.14.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow) (2.0.51)
# Requirement already satisfied: waitress<4 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<8,>=5.0.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (7.1.4)
# Requirement already satisfied: click<9,>=7.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (8.4.2)
# Requirement already satisfied: cloudpickle<4 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (0.119.0)
# Requirement already satisfied: fastapi<1 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (0.138.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (3.1.50)
# Requirement already satisfied: importlib_metadata!=4.7.0,<10,>=3.7.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (9.0.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (1.43.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (1.43.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (1.43.0)
# Requirement already satisfied: packaging<27 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (26.2)
# Requirement already satisfied: protobuf<8,>=3.12.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (6.33.6)
# Requirement already satisfied: pydantic<3,>=2.0.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (2.13.4)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (1.2.2)
# Requirement already satisfied: pyyaml<7,>=5.1 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (2.34.2)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (0.5.5)
# Requirement already satisfied: starlette<2 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlflow-skinny==3.14.0->mlflow) (0.49.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (1.24.2)
# Requirement already satisfied: Mako in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.12)
# Requirement already satisfied: colorama in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from click<9,>=7.0->mlflow-skinny==3.14.0->mlflow) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from cryptography<49,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.14.0->mlflow) (2.55.1)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.14.0->mlflow) (2.7.0)
# Requirement already satisfied: pywin32>=304 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from docker<8,>=4.0.0->mlflow) (312)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fastapi<1->mlflow-skinny==3.14.0->mlflow) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fastapi<1->mlflow-skinny==3.14.0->mlflow) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from Flask<4->mlflow) (3.1.8)
# Requirement already satisfied: gitdb<5,>=4.0.1 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.14.0->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.14.0->mlflow) (5.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.14.0->mlflow) (0.4.2)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from graphene<4->mlflow) (3.2.11)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from importlib_metadata!=4.7.0,<10,>=3.7.0->mlflow-skinny==3.14.0->mlflow) (4.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<4->mlflow) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<4->mlflow) (1.5.0)
# Requirement already satisfied: pillow>=9 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<4->mlflow) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<4->mlflow) (3.3.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.64b0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.14.0->mlflow) (0.64b0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas<3->mlflow) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas<3->mlflow) (2026.2)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.14.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.14.0->mlflow) (2.46.4)
# Requirement already satisfied: six>=1.5 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.14.0->mlflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.14.0->mlflow) (3.18)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.14.0->mlflow) (2026.6.17)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn<2->mlflow) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn<2->mlflow) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: prettytable>=3.9 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from skops<1->mlflow) (3.18.0)
# Requirement already satisfied: greenlet>=1 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.5.3)
# Requirement already satisfied: anyio<5,>=3.6.2 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from starlette<2->mlflow-skinny==3.14.0->mlflow) (4.14.1)
# Requirement already satisfied: h11>=0.8 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from uvicorn<1->mlflow-skinny==3.14.0->mlflow) (0.16.0)
# Requirement already satisfied: botocore<1.44.0,>=1.43.78 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from boto3) (1.43.78)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from boto3) (1.1.0)
# Requirement already satisfied: s3transfer<0.20.0,>=0.19.0 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from boto3) (0.19.2)
# Requirement already satisfied: docutils<=0.19,>=0.18.1 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from awscli) (0.19)
# Requirement already satisfied: rsa<4.8,>=3.1.2 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from awscli) (4.7.2)
# Requirement already satisfied: pyasn1>=0.1.3 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from rsa<4.8,>=3.1.2->awscli) (0.6.3)
# Requirement already satisfied: pycparser in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from cffi>=2.0.0->cryptography<49,>=43.0.0->mlflow) (3.0)
# Requirement already satisfied: wcwidth>=0.3.5 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from prettytable>=3.9->skops<1->mlflow) (0.8.1)
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
## do aws configure if not done in 2nd notebook , or if this is a different pc

# %%
import mlflow
# Step 2: Set up the MLflow tracking server
mlflow.set_tracking_uri("http://ec2-44-192-64-22.compute-1.amazonaws.com:5000/")

# %%
# Set or create an experiment
mlflow.set_experiment("Exp 4 - Handling Imbalanced Data")
# Out:
# <Experiment: artifact_location='s3://mlflow-bucket-3179/4', creation_time=1787593262315, effective_trace_archival_retention=None, experiment_id='4', last_update_time=1787593262315, lifecycle_stage='active', name='Exp 4 - Handling Imbalanced Data', tags={}, trace_location=None, workspace='default'>

# %%
from imblearn.over_sampling import SMOTE, ADASYN
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTEENN
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import mlflow
import mlflow.sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
import time
import json
import joblib

# %%
df = pd.read_csv('reddit_preprocessing.csv').dropna(subset=['clean_comment'])
df.shape
# Out:
# (36662, 2)

# %%
# Step 1: Function to run the experiment
def run_imbalanced_experiment(imbalance_method):
    ngram_range = (1, 3)  # Trigram setting
    max_features = 10000  # Set max_features to 1000 for TF-IDF

    # Step 4: Train-test split before vectorization and resampling
    X_train, X_test, y_train, y_test = train_test_split(df['clean_comment'], df['category'], test_size=0.2, random_state=42, stratify=df['category'])

    # Step 2: Vectorization using TF-IDF, fit on training data only
    vectorizer = TfidfVectorizer(ngram_range=ngram_range, max_features=max_features)
    X_train_vec = vectorizer.fit_transform(X_train)  # Fit on training data
    X_test_vec = vectorizer.transform(X_test)  # Transform test data

    # Step 3: Handle class imbalance based on the selected method (only applied to the training set)
    if imbalance_method == 'class_weights':
        # Use class_weight in Random Forest
        class_weight = 'balanced'
    else:
        class_weight = None  # Do not apply class_weight if using resampling

        # Resampling Techniques (only apply to the training set)
        if imbalance_method == 'oversampling':
            smote = SMOTE(random_state=42)
            X_train_vec, y_train = smote.fit_resample(X_train_vec, y_train)
        elif imbalance_method == 'adasyn':
            adasyn = ADASYN(random_state=42)
            X_train_vec, y_train = adasyn.fit_resample(X_train_vec, y_train)
        elif imbalance_method == 'undersampling':
            rus = RandomUnderSampler(random_state=42)
            X_train_vec, y_train = rus.fit_resample(X_train_vec, y_train)
        elif imbalance_method == 'smote_enn':
            smote_enn = SMOTEENN(random_state=42)
            X_train_vec, y_train = smote_enn.fit_resample(X_train_vec, y_train)

    # Step 5: Define and train a Random Forest model
    with mlflow.start_run() as run:
        # Set tags for the experiment and run
        mlflow.set_tag("mlflow.runName", f"Imbalance_{imbalance_method}_RandomForest_TFIDF_Trigrams")
        mlflow.set_tag("experiment_type", "imbalance_handling")
        mlflow.set_tag("model_type", "RandomForestClassifier")

        # Add a description
        mlflow.set_tag("description", f"RandomForest with TF-IDF Trigrams, imbalance handling method={imbalance_method}")

        # Log vectorizer parameters
        mlflow.log_param("vectorizer_type", "TF-IDF")
        mlflow.log_param("ngram_range", ngram_range)
        mlflow.log_param("vectorizer_max_features", max_features)

        # Log Random Forest parameters
        n_estimators = 200
        max_depth = 15

        mlflow.log_param("n_estimators", n_estimators)
        mlflow.log_param("max_depth", max_depth)
        mlflow.log_param("imbalance_method", imbalance_method)

        # Initialize and train the model
        model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, random_state=42, class_weight=class_weight)
        model.fit(X_train_vec, y_train)

        # Step 6: Make predictions and log metrics
        y_pred = model.predict(X_test_vec)

        # Log accuracy
        accuracy = accuracy_score(y_test, y_pred)
        mlflow.log_metric("accuracy", accuracy)

        # Log classification report
        classification_rep = classification_report(y_test, y_pred, output_dict=True)
        for label, metrics in classification_rep.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)

        # Log confusion matrix
        conf_matrix = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8, 6))
        sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title(f"Confusion Matrix: TF-IDF Trigrams, Imbalance={imbalance_method}")
        confusion_matrix_filename = f"confusion_matrix_{imbalance_method}.png"
        plt.savefig(confusion_matrix_filename)
        mlflow.log_artifact(confusion_matrix_filename)
        plt.close()

        # Log the model
        mlflow.sklearn.log_model(model, f"random_forest_model_tfidf_trigrams_imbalance_{imbalance_method}")

# Step 7: Run experiments for different imbalance methods
imbalance_methods = ['class_weights', 'oversampling', 'adasyn', 'undersampling', 'smote_enn']

for method in imbalance_methods:
    run_imbalanced_experiment(method)
# Out:
# 2026/08/26 17:41:48 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Imbalance_class_weights_RandomForest_TFIDF_Trigrams at: http://ec2-44-192-64-22.compute-1.amazonaws.com:5000/#/experiments/4/runs/7bd7e6a5c17c4dd3b7701afaa93f5c13
# 🧪 View experiment at: http://ec2-44-192-64-22.compute-1.amazonaws.com:5000/#/experiments/4
# 2026/08/26 17:44:13 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Imbalance_oversampling_RandomForest_TFIDF_Trigrams at: http://ec2-44-192-64-22.compute-1.amazonaws.com:5000/#/experiments/4/runs/2bc1d83609a349668d020c45b92b6734
# 🧪 View experiment at: http://ec2-44-192-64-22.compute-1.amazonaws.com:5000/#/experiments/4
# 2026/08/26 17:46:20 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Imbalance_adasyn_RandomForest_TFIDF_Trigrams at: http://ec2-44-192-64-22.compute-1.amazonaws.com:5000/#/experiments/4/runs/4a264dc74b0e43c786831ac8dc9285a9
# 🧪 View experiment at: http://ec2-44-192-64-22.compute-1.amazonaws.com:5000/#/experiments/4
# 2026/08/26 17:48:17 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Imbalance_undersampling_RandomForest_TFIDF_Trigrams at: http://ec2-44-192-64-22.compute-1.amazonaws.com:5000/#/experiments/4/runs/819d362343fd4de0b1eea2e16319d262
# 🧪 View experiment at: http://ec2-44-192-64-22.compute-1.amazonaws.com:5000/#/experiments/4
# 2026/08/26 17:51:08 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Imbalance_smote_enn_RandomForest_TFIDF_Trigrams at: http://ec2-44-192-64-22.compute-1.amazonaws.com:5000/#/experiments/4/runs/35e3877f5e94428b9336d66fd43d3900
# 🧪 View experiment at: http://ec2-44-192-64-22.compute-1.amazonaws.com:5000/#/experiments/4

# %%
#done
